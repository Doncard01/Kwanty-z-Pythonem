# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

sp.init_printing()

# %%
x = sp.Symbol('x', real = True)
k = sp.Symbol('k', real = True, positive = True)
a = sp.Symbol('a', real = True)
psi = sp.Function('\psi')

x, k, a, psi(x)
# Out:
# (x, k, a, \psi(x))

# %%
psi(x).diff(x, x)
# psi(x).diff(x, 2) same as above
# Out:
#   2
#  d
# ───(\psi(x))
#   2
# dx

# %%
-k**2 * psi(x)
# Out:
#   2
# -k ⋅\psi(x)

# %%
eq = sp.Eq(psi(x).diff(x, x), -k**2 * psi(x))
eq
# Out:
#   2
#  d               2
# ───(\psi(x)) = -k ⋅\psi(x)
#   2
# dx

# %%
sol = sp.dsolve(eq, psi(x), ics={psi(0): 0, psi(a): 0})
sol
# Out:
# \psi(x) = 0

# %%
sol = sp.dsolve(eq, psi(x), ics={psi(0): 0, psi(a): 0}) 
sol # rozwiązanie bez fizycznego sensu
# Out:
# \psi(x) = 0

# %%
plt.hlines(np.arange(1, 10)**2, 0, 1)
